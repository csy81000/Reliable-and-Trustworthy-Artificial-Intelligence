# %%
# !nvidia-smi
# Out:
# Fri Jun  5 12:09:00 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.20             Driver Version: 580.126.20     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        On  |   00000000:01:00.0 Off |                  N/A |
# | 55%   59C    P1            295W /  600W |   27401MiB /  32607MiB |      1%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone --recursive https://github.com/Verified-Intelligence/alpha-beta-CROWN.git
# %cd alpha-beta-CROWN
# Out:
# Cloning into 'alpha-beta-CROWN'...
# remote: Enumerating objects: 1854, done.
# remote: Counting objects: 100% (642/642), done.
# remote: Compressing objects: 100% (367/367), done.
# remote: Total 1854 (delta 326), reused 389 (delta 272), pack-reused 1212 (from 2)
# Receiving objects: 100% (1854/1854), 82.98 MiB | 23.30 MiB/s, done.
# Resolving deltas: 100% (985/985), done.
# Submodule 'auto_LiRPA' (https://github.com/Verified-Intelligence/auto_LiRPA.git) registered for path 'auto_LiRPA'
# Cloning into '/home/hun/workspace/alpha-beta-CROWN/auto_LiRPA'...
# remote: Enumerating objects: 1296, done.
# remote: Counting objects: 100% (825/825), done.
# remote: Compressing objects: 100% (639/639), done.
# remote: Total 1296 (delta 454), reused 193 (delta 186), pack-reused 471 (from 3)
# Receiving objects: 100% (1296/1296), 39.48 MiB | 25.03 MiB/s, done.
# Resolving deltas: 100% (614/614), done.
# Submodule path 'auto_LiRPA': checked out 'a050a3d61f4cb68b108fa7f07dcb3e4d7ef304df'
# ...

# %%
# !pip install -r complete_verifier/requirements.txt
# %cd auto_LiRPA
# !pip install -e .

# %cd ..
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'complete_verifier/requirements.txt'
# /home/hun/workspace/alpha-beta-CROWN/auto_LiRPA
# Obtaining file:///home/hun/workspace/alpha-beta-CROWN/auto_LiRPA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.1/888.1 MB 69.9 MB/s  0:00:12m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 122.6 MB/s  0:00:030:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 120.4 MB/s  0:00:00
# ...

# %%
# !pip install onnx onnxruntime onnx2pytorch onnxoptimizer skl2onnx gurobipy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 71.7 MB/s  0:00:00
# ...

# %%
# 내장된 MNIST 샘플 설정 파일로 알파-베타-크라운 구동 [cite: 40, 53]python abcrown.py --config exp_configs/tutorial_examples/cifar_resnet_2b.yam
# %cd complete_verifier
# !python abcrown.py --config exp_configs/tutorial_examples/cifar_resnet_2b.yaml
# Out:
# /home/hun/workspace/alpha-beta-CROWN/complete_verifier
# INFO     12:12:44     [tensor_storage.py:70] Hugepage enabled for branch-and-bound domains.
# Configurations:
#
# general:
#   device: cuda
#   seed: 100
#   conv_mode: patches
#   deterministic: false
#   double_fp: false
#   loss_reduction_func: sum
#   sparse_alpha: true
#   sparse_interm: true
#   save_adv_example: false
#   verify_onnxruntime_output: false
#   eval_adv_example: false
#   onnx_adv_example: false
#   show_adv_example: false
#   precompile_jit: false
#   reset_seed_after_precompile: false
#   prepare_only: false
#   complete_verifier: bab
#   enable_incomplete_verification: true
#   csv_name: null
#   results_file: out.txt
#   root_path: ''
#   deterministic_opt: false
#   graph_optimizer: 'Customized("custom_graph_optimizer", "default_optimizer")'
#   buffer_has_batchdim: false
#   save_output: false
#   output_file: out.pkl
#   return_optimized_model: false
#   store_all_specs_on_cpu: false
# ...
