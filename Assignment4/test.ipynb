# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !git clone --recursive https://github.com/Verified-Intelligence/alpha-beta-CROWN.git
# Out:
# fatal: destination path 'alpha-beta-CROWN' already exists and is not an empty directory.

# %%
# %cd /content/alpha-beta-CROWN
# !conda env update -n base -f complete_verifier/environment.yaml
# Out:
# /content/alpha-beta-CROWN
# Channels:
#  - gurobi
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==5.1=1_gnu
#     - adwaita-icon-theme==48.0=h06a4308_0
#     - appdirs==1.4.4=pyhd3eb1b0_0
#     - at-spi2-atk==2.34.2=hfac8509_1
#     - at-spi2-core==2.36.0=h597f2ad_2
#     - atk-1.0==2.36.0=ha1a6a79_0
#     - blas==1.0=mkl
#     - bottleneck==1.4.2=py311haa0f9ac_1
#     - bzip2==1.0.8=h5eee18b_6
#     - c-ares==1.34.5=hef5626c_0
#     - ca-certificates==2025.11.4=h06a4308_0
#     - cairo==1.18.4=h44eff21_0
#     - cffi==2.0.0=py311h4eded50_1
#     - cfgv==3.4.0=py311h06a4308_0
#     - dbus==1.16.2=h5bd4931_0
#     - distlib==0.4.0=py311hee96239_0
#     - epoxy==1.5.4=h7f8727e_2
#     - expat==2.7.3=h3385a95_0
#     - font-ttf-dejavu-sans-mono==2.37=hd3eb1b0_0
#     - font-ttf-inconsolata==2.001=hcb22688_0
#     - font-ttf-source-code-pro==2.030=hd3eb1b0_0
#     - font-ttf-ubuntu==0.83=h8b1ccd4_0
#     - fontconfig==2.15.0=h2c49b7f_0
#     - fonts-anaconda==1=h8fa9717_0
#     - fonts-conda-ecosystem==1=hd3eb1b0_0
#     - freetype==2.13.3=h4a9f257_0
#     - fribidi==1.0.10=h7b6447c_0
#     - gdk-pixbuf==2.42.10=h64b468e_2
#     - gettext==0.21.0=hedfda30_2
#     - giflib==5.2.2=h5eee18b_0
#     - glib==2.84.4=h5bdd934_0
#     - glib-tools==2.84.4=h8875d55_0
#     - gobject-introspection==1.84.0=py311hcb37abf_0
#     - graphite2==1.3.14=h295c915_1
#     - graphviz==12.2.1=h053244a_2
#     - gtk3==3.24.21=h40e4fd3_8
#     - gts==0.7.6=hb67d8dd_3
#     - gurobi==12.0.0=py311_0
#     - harfbuzz==10.2.0=hdfddeaa_1
#     - hicolor-icon-theme==0.17=h06a4308_2
#     - icu==73.1=h6a678d5_0
#     - identify==2.5.5=py311h06a4308_0
#     - iniconfig==2.1.0=py311h06a4308_0
#     - intel-openmp==2025.0.0=h06a4308_1171
#     - jansson==2.14=h5eee18b_1
#     - joblib==1.5.2=py311h06a4308_0
#     - jpeg==9f=h5ce9db8_0
#     - lcms2==2.17=heab6991_0
#     - ld_impl_linux-64==2.44=h153f514_2
#     - lerc==4.0.0=h6a678d5_0
#     - libboost==1.88.0=h9d9b81f_0
#     - libcups==2.4.2=h252cb56_2
#     - libcurl==8.16.0=heebcbe5_0
#     - libdeflate==1.22=h5eee18b_0
#     - libev==4.33=h7f8727e_1
#     - libffi==3.4.4=h6a678d5_1
#     - libgcc==15.2.0=h69a1729_7
#     - libgcc-ng==15.2.0=h166f726_7
#     - libgd==2.3.3=h536bbd8_4
#     - libgfortran==15.2.0=h166f726_7
#     - libgfortran-ng==15.2.0=h166f726_7
#     - libgfortran5==15.2.0=hc633d37_7
#     - libglib==2.84.4=h77a78f3_0
#     - libgomp==15.2.0=h4751f2c_7
#     - libiconv==1.16=h5eee18b_3
#     - libidn2==2.3.8=hf80d704_0
#     - libnghttp2==1.67.1=h697f920_0
#     - libnsl==2.0.0=h5eee18b_0
#     - libopenjpeg==2.5.4=hee96239_1
#     - libpng==1.6.50=h2ed474d_0
#     - librsvg==2.56.3=hb0330b6_2
#     - libssh2==1.11.1=h251f7ec_0
#     - libstdcxx==15.2.0=h39759b7_7
#     - libstdcxx-ng==15.2.0=hc03a8fd_7
#     - libtiff==4.7.1=h029b1ac_0
#     - libtool==2.4.7=h6a678d5_0
#     - libunistring==1.3=hb25bd0a_0
#     - libuuid==1.41.5=h5eee18b_0
#     - libwebp==1.6.0=h089d785_0
#     - libwebp-base==1.6.0=hb7bb969_0
#     - libxcb==1.17.0=h9b100fa_0
#     - libxml2==2.13.9=h2c43086_0
#     - libzlib==1.3.1=hb25bd0a_0
#     - lz4-c==1.9.4=h6a678d5_1
#     - markdown-it-py==4.0.0=py311h06a4308_0
#     - mdurl==0.1.2=py311h06a4308_0
#     - mkl==2025.0.0=hacee8c2_941
#     - mkl-service==2.5.2=py311hacdc0fc_0
#     - mkl_fft==2.1.1=py311h8fe796d_0
#     - mkl_random==1.3.0=py311h505adc9_0
#     - mpmath==1.3.0=py311h06a4308_0
#     - ncurses==6.5=h7934f7d_0
#     - ninja==1.13.1=h06a4308_0
#     - ninja-base==1.13.1=h0f57076_0
#     - nodeenv==1.9.1=py311h06a4308_0
#     - nspr==4.37=h8459abe_0
#     - nss==3.117=h3135ca0_0
#     - numexpr==2.14.1=py311h41d4191_0
#     - numpy-base==2.3.5=py311h00548fb_0
#     - openjpeg==2.5.4=h4e0627c_1
#     - openssl==3.0.18=hd6dcaed_0
#     - packaging==25.0=py311h06a4308_1
#     - pandas==2.3.3=py311h23c847b_1
#     - pango==1.50.7=h668f713_2
#     - pcre2==10.46=hf426167_0
#     - pip==25.3=pyhc872135_0
#     - pixman==0.46.4=h7934f7d_0
#     - platformdirs==4.5.0=py311h06a4308_0
#     - pluggy==1.5.0=py311h06a4308_0
#     - poppler==24.09.0=h696634e_4
#     - poppler-data==0.4.12=h06a4308_0
#     - pre-commit==3.4.0=py311h06a4308_1
#     - protobuf==6.33.0=py311hbdd6827_0
#     - psutil==7.0.0=py311hee96239_1
#     - pthread-stubs==0.3=h0ce48e5_1
#     - pycparser==2.23=py311h06a4308_0
#     - pygments==2.19.2=py311h06a4308_0
#     - pytest==8.4.2=py311h06a4308_0
#     - pytest-cov==7.0.0=py311h06a4308_0
#     - python==3.11.14=h6fa692b_0
#     - python-dateutil==2.9.0post0=py311h06a4308_2
#     - python-graphviz==0.16=pyhd3eb1b0_1
#     - python-tzdata==2025.2=pyhd3eb1b0_0
#     - pytz==2025.2=py311h06a4308_0
#     - pyyaml==6.0.3=py311h591646f_0
#     - readline==8.3=hc2a1206_0
#     - rich==14.2.0=py311h06a4308_0
#     - scikit-learn==1.7.2=py311h505adc9_0
#     - scipy==1.16.3=py311h33bc11c_0
#     - setuptools==80.9.0=py311h06a4308_0
#     - six==1.17.0=py311h06a4308_0
#     - sortedcontainers==2.4.0=pyhd3eb1b0_0
#     - sqlite==3.51.0=h2a70700_0
#     - tbb==2022.0.0=hdb19cb5_0
#     - tbb-devel==2022.0.0=hdb19cb5_0
#     - threadpoolctl==3.5.0=py311h92b7b1e_0
#     - tk==8.6.15=h54e0aa7_0
#     - tqdm==4.67.1=py311h7040dfc_1
#     - tzdata==2025b=h04d1e81_0
#     - ukkonen==1.0.1=py311hdb19cb5_1
#     - virtualenv==20.28.0=py311h06a4308_0
#     - wheel==0.45.1=py311h06a4308_0
#     - xorg-libx11==1.8.12=h9b100fa_1
#     - xorg-libxau==1.0.12=h9b100fa_0
#     - xorg-libxcomposite==0.4.6=h9b100fa_2
#     - xorg-libxcursor==1.2.3=h9b100fa_0
#     - xorg-libxdamage==1.1.6=h9b100fa_0
#     - xorg-libxdmcp==1.1.5=h9b100fa_0
#     - xorg-libxext==1.3.6=h9b100fa_0
#     - xorg-libxfixes==6.0.1=h9b100fa_0
#     - xorg-libxi==1.8.2=h9b100fa_0
#     - xorg-libxinerama==1.1.5=h50385e7_1
#     - xorg-libxrandr==1.5.4=h9b100fa_0
#     - xorg-libxrender==0.9.12=h9b100fa_0
#     - xorg-libxtst==1.2.5=h9b100fa_3
#     - xorg-xorgproto==2024.1=h5eee18b_1
#     - xz==5.6.4=h5eee18b_1
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.3.1=hb25bd0a_0
#     - zstd==1.5.7=h11fc155_0
#   pinned specs:
#     - cuda-version=12
#     - python=3.12
#     - python_abi=3.12[build=*cp312*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
# %cd /content/alpha-beta-CROWN/auto_LiRPA
# !pip install -e .

# %cd /content/alpha-beta-CROWN/complete_verifier
# !pip install -r requirements.txt
# Out:
# /content/alpha-beta-CROWN/auto_LiRPA
# Obtaining file:///content/alpha-beta-CROWN/auto_LiRPA
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch<2.9.0,>=2.0.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (2.8.0)
# Requirement already satisfied: torchvision<0.24.0,>=0.12.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (0.23.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (24.2)
# Requirement already satisfied: pytest==8.1.1 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (8.1.1)
# Requirement already satisfied: pylint>=2.15 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (4.0.5)
# Requirement already satisfied: pytest-order>=1.0.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (1.4.0)
# Requirement already satisfied: pytest-mock>=3.14 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (3.15.1)
# Requirement already satisfied: appdirs>=1.4 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (1.4.4)
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (6.0.3)
# Requirement already satisfied: ninja>=1.10 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (1.13.0)
# Requirement already satisfied: tqdm>=4.64 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (4.67.1)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (0.21)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/site-packages (from pytest==8.1.1->auto-LiRPA==0.7.1) (2.3.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /usr/local/lib/python3.11/site-packages (from pytest==8.1.1->auto-LiRPA==0.7.1) (1.5.0)
# Requirement already satisfied: astroid<=4.1.dev0,>=4.0.2 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (4.0.4)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (0.4.1)
# Requirement already satisfied: isort!=5.13,<9,>=5 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (8.0.1)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (0.7.0)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (4.3.6)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (0.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.4.0->torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (65.6.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/site-packages (from torchvision<0.24.0,>=0.12.0->auto-LiRPA==0.7.1) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.0.3)
# Installing collected packages: auto-LiRPA
#   Attempting uninstall: auto-LiRPA
#     Found existing installation: auto-LiRPA 0.7.1
#     Uninstalling auto-LiRPA-0.7.1:
#       Successfully uninstalled auto-LiRPA-0.7.1
#   DEPRECATION: Legacy editable install of auto-LiRPA==0.7.1 from file:///content/alpha-beta-CROWN/auto_LiRPA (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for auto-LiRPA
# Successfully installed auto-LiRPA-0.7.1
# /content/alpha-beta-CROWN/complete_verifier
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# 1. 꼬여버린 기존 폴더 깔끔하게 삭제 (초기화)
# !rm -rf /content/alpha-beta-CROWN

# 2. 작업 위치를 기본 폴더로 이동
# %cd /content

# 3. 하위 모듈(auto_LiRPA 포함)까지 강제로 모두 가져오기
# !git clone --recursive https://github.com/Verified-Intelligence/alpha-beta-CROWN.git

# 4. Conda 환경 업데이트 (requirements.txt 에러는 이걸로 대체 및 해결됩니다)
# %cd /content/alpha-beta-CROWN
# !conda env update -n base -f complete_verifier/environment.yaml

# 5. auto_LiRPA 설치 진행
# %cd /content/alpha-beta-CROWN/auto_LiRPA
# !pip install -e .
# Out:
# /content
# Cloning into 'alpha-beta-CROWN'...
# remote: Enumerating objects: 1854, done.
# remote: Counting objects: 100% (642/642), done.
# remote: Compressing objects: 100% (367/367), done.
# remote: Total 1854 (delta 326), reused 389 (delta 272), pack-reused 1212 (from 2)
# Receiving objects: 100% (1854/1854), 82.98 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (985/985), done.
# Submodule 'auto_LiRPA' (https://github.com/Verified-Intelligence/auto_LiRPA.git) registered for path 'auto_LiRPA'
# Cloning into '/content/alpha-beta-CROWN/auto_LiRPA'...
# remote: Enumerating objects: 1296, done.
# remote: Counting objects: 100% (825/825), done.
# remote: Compressing objects: 100% (639/639), done.
# remote: Total 1296 (delta 454), reused 193 (delta 186), pack-reused 471 (from 3)
# Receiving objects: 100% (1296/1296), 39.48 MiB | 12.51 MiB/s, done.
# Resolving deltas: 100% (614/614), done.
# Submodule path 'auto_LiRPA': checked out 'a050a3d61f4cb68b108fa7f07dcb3e4d7ef304df'
# /content/alpha-beta-CROWN
# Channels:
#  - gurobi
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==5.1=1_gnu
#     - adwaita-icon-theme==48.0=h06a4308_0
#     - appdirs==1.4.4=pyhd3eb1b0_0
#     - at-spi2-atk==2.34.2=hfac8509_1
#     - at-spi2-core==2.36.0=h597f2ad_2
#     - atk-1.0==2.36.0=ha1a6a79_0
#     - blas==1.0=mkl
#     - bottleneck==1.4.2=py311haa0f9ac_1
#     - bzip2==1.0.8=h5eee18b_6
#     - c-ares==1.34.5=hef5626c_0
#     - ca-certificates==2025.11.4=h06a4308_0
#     - cairo==1.18.4=h44eff21_0
#     - cffi==2.0.0=py311h4eded50_1
#     - cfgv==3.4.0=py311h06a4308_0
#     - dbus==1.16.2=h5bd4931_0
#     - distlib==0.4.0=py311hee96239_0
#     - epoxy==1.5.4=h7f8727e_2
#     - expat==2.7.3=h3385a95_0
#     - font-ttf-dejavu-sans-mono==2.37=hd3eb1b0_0
#     - font-ttf-inconsolata==2.001=hcb22688_0
#     - font-ttf-source-code-pro==2.030=hd3eb1b0_0
#     - font-ttf-ubuntu==0.83=h8b1ccd4_0
#     - fontconfig==2.15.0=h2c49b7f_0
#     - fonts-anaconda==1=h8fa9717_0
#     - fonts-conda-ecosystem==1=hd3eb1b0_0
#     - freetype==2.13.3=h4a9f257_0
#     - fribidi==1.0.10=h7b6447c_0
#     - gdk-pixbuf==2.42.10=h64b468e_2
#     - gettext==0.21.0=hedfda30_2
#     - giflib==5.2.2=h5eee18b_0
#     - glib==2.84.4=h5bdd934_0
#     - glib-tools==2.84.4=h8875d55_0
#     - gobject-introspection==1.84.0=py311hcb37abf_0
#     - graphite2==1.3.14=h295c915_1
#     - graphviz==12.2.1=h053244a_2
#     - gtk3==3.24.21=h40e4fd3_8
#     - gts==0.7.6=hb67d8dd_3
#     - gurobi==12.0.0=py311_0
#     - harfbuzz==10.2.0=hdfddeaa_1
#     - hicolor-icon-theme==0.17=h06a4308_2
#     - icu==73.1=h6a678d5_0
#     - identify==2.5.5=py311h06a4308_0
#     - iniconfig==2.1.0=py311h06a4308_0
#     - intel-openmp==2025.0.0=h06a4308_1171
#     - jansson==2.14=h5eee18b_1
#     - joblib==1.5.2=py311h06a4308_0
#     - jpeg==9f=h5ce9db8_0
#     - lcms2==2.17=heab6991_0
#     - ld_impl_linux-64==2.44=h153f514_2
#     - lerc==4.0.0=h6a678d5_0
#     - libboost==1.88.0=h9d9b81f_0
#     - libcups==2.4.2=h252cb56_2
#     - libcurl==8.16.0=heebcbe5_0
#     - libdeflate==1.22=h5eee18b_0
#     - libev==4.33=h7f8727e_1
#     - libffi==3.4.4=h6a678d5_1
#     - libgcc==15.2.0=h69a1729_7
#     - libgcc-ng==15.2.0=h166f726_7
#     - libgd==2.3.3=h536bbd8_4
#     - libgfortran==15.2.0=h166f726_7
#     - libgfortran-ng==15.2.0=h166f726_7
#     - libgfortran5==15.2.0=hc633d37_7
#     - libglib==2.84.4=h77a78f3_0
#     - libgomp==15.2.0=h4751f2c_7
#     - libiconv==1.16=h5eee18b_3
#     - libidn2==2.3.8=hf80d704_0
#     - libnghttp2==1.67.1=h697f920_0
#     - libnsl==2.0.0=h5eee18b_0
#     - libopenjpeg==2.5.4=hee96239_1
#     - libpng==1.6.50=h2ed474d_0
#     - librsvg==2.56.3=hb0330b6_2
#     - libssh2==1.11.1=h251f7ec_0
#     - libstdcxx==15.2.0=h39759b7_7
#     - libstdcxx-ng==15.2.0=hc03a8fd_7
#     - libtiff==4.7.1=h029b1ac_0
#     - libtool==2.4.7=h6a678d5_0
#     - libunistring==1.3=hb25bd0a_0
#     - libuuid==1.41.5=h5eee18b_0
#     - libwebp==1.6.0=h089d785_0
#     - libwebp-base==1.6.0=hb7bb969_0
#     - libxcb==1.17.0=h9b100fa_0
#     - libxml2==2.13.9=h2c43086_0
#     - libzlib==1.3.1=hb25bd0a_0
#     - lz4-c==1.9.4=h6a678d5_1
#     - markdown-it-py==4.0.0=py311h06a4308_0
#     - mdurl==0.1.2=py311h06a4308_0
#     - mkl==2025.0.0=hacee8c2_941
#     - mkl-service==2.5.2=py311hacdc0fc_0
#     - mkl_fft==2.1.1=py311h8fe796d_0
#     - mkl_random==1.3.0=py311h505adc9_0
#     - mpmath==1.3.0=py311h06a4308_0
#     - ncurses==6.5=h7934f7d_0
#     - ninja==1.13.1=h06a4308_0
#     - ninja-base==1.13.1=h0f57076_0
#     - nodeenv==1.9.1=py311h06a4308_0
#     - nspr==4.37=h8459abe_0
#     - nss==3.117=h3135ca0_0
#     - numexpr==2.14.1=py311h41d4191_0
#     - numpy-base==2.3.5=py311h00548fb_0
#     - openjpeg==2.5.4=h4e0627c_1
#     - openssl==3.0.18=hd6dcaed_0
#     - packaging==25.0=py311h06a4308_1
#     - pandas==2.3.3=py311h23c847b_1
#     - pango==1.50.7=h668f713_2
#     - pcre2==10.46=hf426167_0
#     - pip==25.3=pyhc872135_0
#     - pixman==0.46.4=h7934f7d_0
#     - platformdirs==4.5.0=py311h06a4308_0
#     - pluggy==1.5.0=py311h06a4308_0
#     - poppler==24.09.0=h696634e_4
#     - poppler-data==0.4.12=h06a4308_0
#     - pre-commit==3.4.0=py311h06a4308_1
#     - protobuf==6.33.0=py311hbdd6827_0
#     - psutil==7.0.0=py311hee96239_1
#     - pthread-stubs==0.3=h0ce48e5_1
#     - pycparser==2.23=py311h06a4308_0
#     - pygments==2.19.2=py311h06a4308_0
#     - pytest==8.4.2=py311h06a4308_0
#     - pytest-cov==7.0.0=py311h06a4308_0
#     - python==3.11.14=h6fa692b_0
#     - python-dateutil==2.9.0post0=py311h06a4308_2
#     - python-graphviz==0.16=pyhd3eb1b0_1
#     - python-tzdata==2025.2=pyhd3eb1b0_0
#     - pytz==2025.2=py311h06a4308_0
#     - pyyaml==6.0.3=py311h591646f_0
#     - readline==8.3=hc2a1206_0
#     - rich==14.2.0=py311h06a4308_0
#     - scikit-learn==1.7.2=py311h505adc9_0
#     - scipy==1.16.3=py311h33bc11c_0
#     - setuptools==80.9.0=py311h06a4308_0
#     - six==1.17.0=py311h06a4308_0
#     - sortedcontainers==2.4.0=pyhd3eb1b0_0
#     - sqlite==3.51.0=h2a70700_0
#     - tbb==2022.0.0=hdb19cb5_0
#     - tbb-devel==2022.0.0=hdb19cb5_0
#     - threadpoolctl==3.5.0=py311h92b7b1e_0
#     - tk==8.6.15=h54e0aa7_0
#     - tqdm==4.67.1=py311h7040dfc_1
#     - tzdata==2025b=h04d1e81_0
#     - ukkonen==1.0.1=py311hdb19cb5_1
#     - virtualenv==20.28.0=py311h06a4308_0
#     - wheel==0.45.1=py311h06a4308_0
#     - xorg-libx11==1.8.12=h9b100fa_1
#     - xorg-libxau==1.0.12=h9b100fa_0
#     - xorg-libxcomposite==0.4.6=h9b100fa_2
#     - xorg-libxcursor==1.2.3=h9b100fa_0
#     - xorg-libxdamage==1.1.6=h9b100fa_0
#     - xorg-libxdmcp==1.1.5=h9b100fa_0
#     - xorg-libxext==1.3.6=h9b100fa_0
#     - xorg-libxfixes==6.0.1=h9b100fa_0
#     - xorg-libxi==1.8.2=h9b100fa_0
#     - xorg-libxinerama==1.1.5=h50385e7_1
#     - xorg-libxrandr==1.5.4=h9b100fa_0
#     - xorg-libxrender==0.9.12=h9b100fa_0
#     - xorg-libxtst==1.2.5=h9b100fa_3
#     - xorg-xorgproto==2024.1=h5eee18b_1
#     - xz==5.6.4=h5eee18b_1
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.3.1=hb25bd0a_0
#     - zstd==1.5.7=h11fc155_0
#   pinned specs:
#     - cuda-version=12
#     - python=3.12
#     - python_abi=3.12[build=*cp312*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.
#
#
# /content/alpha-beta-CROWN/auto_LiRPA
# Obtaining file:///content/alpha-beta-CROWN/auto_LiRPA
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch<2.9.0,>=2.0.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (2.8.0)
# Requirement already satisfied: torchvision<0.24.0,>=0.12.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (0.23.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (24.2)
# Requirement already satisfied: pytest==8.1.1 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (8.1.1)
# Requirement already satisfied: pylint>=2.15 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (4.0.5)
# Requirement already satisfied: pytest-order>=1.0.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (1.4.0)
# Requirement already satisfied: pytest-mock>=3.14 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (3.15.1)
# Requirement already satisfied: appdirs>=1.4 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (1.4.4)
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (6.0.3)
# Requirement already satisfied: ninja>=1.10 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (1.13.0)
# Requirement already satisfied: tqdm>=4.64 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (4.67.1)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.11/site-packages (from auto-LiRPA==0.7.1) (0.21)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/site-packages (from pytest==8.1.1->auto-LiRPA==0.7.1) (2.3.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /usr/local/lib/python3.11/site-packages (from pytest==8.1.1->auto-LiRPA==0.7.1) (1.5.0)
# Requirement already satisfied: astroid<=4.1.dev0,>=4.0.2 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (4.0.4)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (0.4.1)
# Requirement already satisfied: isort!=5.13,<9,>=5 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (8.0.1)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (0.7.0)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (4.3.6)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.11/site-packages (from pylint>=2.15->auto-LiRPA==0.7.1) (0.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.11/site-packages (from torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.4.0->torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (65.6.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/site-packages (from torchvision<0.24.0,>=0.12.0->auto-LiRPA==0.7.1) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.9.0,>=2.0.0->auto-LiRPA==0.7.1) (3.0.3)
# Installing collected packages: auto-LiRPA
#   DEPRECATION: Legacy editable install of auto-LiRPA==0.7.1 from file:///content/alpha-beta-CROWN/auto_LiRPA (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for auto-LiRPA
# Successfully installed auto-LiRPA-0.7.1
